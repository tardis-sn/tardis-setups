# %% [markdown]
# **In this notebook, I've ran a simulation and plotted the spectrum of the setup in `2022\sn_radtrans_compare\blondin_model_compare_01.yml`**
#
# **I'm using Windows 10, and I've installed the conda environment on WSL2 along with TARDIS**
#
# **The configuration file is almost the same as the one I've forked, I've only changed the dataset path, and the number of threads**
#
# ---

# %% [markdown]
# ## Importing the required dependencies

# %%
import os
from tardis import run_tardis
from tardis.io.atom_data.util import download_atom_data
# Out:
# Iterations:          0/? [00:00<?, ?it/s]
# Packets:             0/? [00:00<?, ?it/s]

# %% [markdown]
# ## Downloading the atomic data

# %%
# The data are automatically downloaded
download_atom_data('kurucz_cd23_chianti_H_He')

# %% [markdown]
# ## Changing Directory to `2022\sn_radtrans_compare`

# %%
os.chdir('2022/sn_radtrans_compare')

# %% [markdown]
# ## Running the Simulation

# %%
sim = run_tardis('blondin_model_compare_01.yml')
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]
#
# 	Reading Atomic Data from /home/nooreldeensalah/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:92)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:204)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:209)
# [tardis.plasma.properties.atomic][WARNING]
# 	Zeta_data missing - replaced with 1s. Missing ions: [(14, 15), (16, 17), (20, 21), (26, 27), (27, 28), (28, 29)] (atomic.py:602)
# [py.warnings         ][WARNING]
# 	/mnt/c/Users/NoorEldeenSalah/Downloads/tardis/tardis/plasma/properties/radiative_properties.py:93: RuntimeWarning: invalid value encountered in true_divide
#   (g_lower * n_upper) / (g_upper * n_lower)
#  (warnings.py:110)
# [tardis.plasma.properties.atomic][WARNING]
# ...

# %% [markdown]
# ## Plotting the Spectrum

# %%
# %pylab inline

from matplotlib.pyplot import *

spectrum = sim.runner.spectrum
spectrum_virtual = sim.runner.spectrum_virtual
spectrum_integrated = sim.runner.spectrum_integrated

figure(figsize=(10,6))
spectrum.plot(label='normal packets')
spectrum_virtual.plot(label='virtual packets')
spectrum_integrated.plot(label='formal integral')
xlabel('Wavelength [$\AA$]')
ylabel('Luminosity Density [erg/s/$\AA$]')
legend()
xlim(500, 9000)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [py.warnings         ][WARNING]
# 	/mnt/c/Users/NoorEldeenSalah/Downloads/tardis/tardis/montecarlo/base.py:262: UserWarning: MontecarloRunner.spectrum_virtualis zero. Please run the montecarlo simulation withno_of_virtual_packets > 0
#   UserWarning,
#  (warnings.py:110)
# (500.0, 9000.0)

# %% [markdown]
# ## References

# %% [markdown]
# - [TARDIS Quickstart](https://tardis-sn.github.io/tardis/quickstart.html)
